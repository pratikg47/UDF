# %%
# !pip install -r requirements.txt
from warpdrive import WarpDrive
import matplotlib.pyplot as plt

wd = WarpDrive()


png = wd.get_args("png")
wd.save_png(png)


TEXT = wd.get_args("TEXT")
print(TEXT)

PDF = wd.get_args("PDF")
MECLASS = wd.get_args("MECLASS")
MET = wd.get_args("MET")
SS = wd.get_args("SS")
VECM = wd.get_args("VECM")
RFR = wd.get_args("RFR")
LRC = wd.get_args("LRC")
STR = wd.get_args("STR")
INT = wd.get_args("INT")
FLOAT = wd.get_args("FLOAT")
BL = wd.get_args("BL")
# your code here
# Out:
# ...
# [NimbusFS] Using cached file: /tmp/tmpfec90imh
# [NimbusFS] Using cached file: /tmp/tmppc87zlfz
# [NimbusFS] Using cached file: /tmp/tmpdu486n9h
# Directory '../models/' removed successfully.
# Model loaded successfully
# Directory '../models/' removed successfully.
# /usr/local/lib/python3.10/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator DecisionTreeRegressor from version 1.2.0 when using version 1.1.3. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /usr/local/lib/python3.10/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator RandomForestRegressor from version 1.2.0 when using version 1.1.3. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# ...
